# %% [markdown]
# # Solución - Ejercicio 1 - Películas
#
# ## Pasos a seguir:
#
# 1. Archivo **movies**
#
#     1. Crear el Dataframe
#
#     2. ¿Conocemos los datos?
#         - Columnas
#         - Tamaño
#         - Tipos de datos
#
#     3. Renombrar las columnas ID, Titulo, Genero
#
#     4. ¿Hay Valores nulos (NaN) en las columnas?
#
#     5. Regresa algunas secciones
#         - Segunda Columna ¿Acaso los valores son únicos?
#         - Registro número 40
#
# 2. Archivo **ratings**
#
#     1. ¿Conocemos los datos?
#         - ¿Entendemos todos?
#
#     2. Obtengamos los estadísticos básicos de las calificaciones
#
#     3. Cambiemos la escala de las calificaciones de un máximo de 5 a 100
#
#     4. ¿Cuántas calificaciones tiene cada película? ¿Cuál es la calificación media de cada uno?
#         Nota: agrupen las calificaciones y cuenten las clasificaciones
#
#     5. ¿cuáles son las películas son las 20 mejores  y peores según las calificaciones? ¿Cuáles son las más calificadas?
#
# 3. Pongamonos serios:
#
#     1. La columna de genero en el DataFrame tiene divisiones, ¿podemos poner cada genero en una columna?
#     2. Concatena las nuevas columnas y quita la columna vieja

# %% [markdown]
# ## 1. Archivo *movies*

# %% [markdown]
# ### 1. Creamos los DataFrames

# %%
import pandas as pd

data1=pd.read_csv('movielens/movies.csv')

# %%
# Creacion de los dataframes 
df1=pd.DataFrame(data1)

# %% [markdown]
# ### 2. ¿Conocemos los datos?

# %%
#Podemos imprimir el dataframe
#df1

#Podemos imprimir solo los primeros 5 registros 
df1.head()
# Out:
#    ID                              Titulo  \
# 0   1                    Toy Story (1995)
# 1   2                      Jumanji (1995)
# 2   3             Grumpier Old Men (1995)
# 3   4            Waiting to Exhale (1995)
# 4   5  Father of the Bride Part II (1995)
#
#                                         Genero
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Tamaño del Dataframe
df1.shape
# Out:
# (9742, 3)

# %% [markdown]
# ### 3. Renombra las columnas

# %%
df1.columns=['ID','Titulo','Genero']
df1.head()
# Out:
#    ID                              Titulo  \
# 0   1                    Toy Story (1995)
# 1   2                      Jumanji (1995)
# 2   3             Grumpier Old Men (1995)
# 3   4            Waiting to Exhale (1995)
# 4   5  Father of the Bride Part II (1995)
#
#                                         Genero
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# ### 4. ¿Hay Valores nulos (NaN) en las columnas?

# %%
df1.isnull().any()
# Out:
# ID        False
# Titulo    False
# Genero    False
# dtype: bool

# %% [markdown]
# ### 5. Algunas secciones

# %%
# Segunda columna 
pd.DataFrame(df1['Titulo']).head()
# Out:
#                                Titulo
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)

# %%
#  Renglon 40 
pd.DataFrame(df1.iloc[39]).head()
# Out:
#                         39
# ID                      43
# Titulo  Restoration (1995)
# Genero               Drama

# %% [markdown]
# ## 2. Archivo *ratings*

# %% [markdown]
# ### 1. ¿Conocemos los datos?

# %%
#Lectura de los datos 
data2=pd.read_csv('movielens/ratings.csv')

# Creacion de los dataframes 
df2=pd.DataFrame(data2)

# Encabezados 
df2.head()

# Existen datos del usuario que las califico, las peliculas calificadas por el, la calificación y la hora en que fueron calificadas
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# ### 2. Obtengamos los estadísticos básicos de las calificaciones

# %%
#Principales estadísticos descriptivos
df2['rating'].describe()

# Count - Cuantos registros existen
# Mean  - Promedio
# Std   - Desviación estándar 
# min   - Valor Mínimo
# 25%   - 25 percentil 
# 50%   - 50 percentil 
# 75%   - 75 percentil 
# max   - Valor máximo
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: rating, dtype: float64

# %% [markdown]
# ### 3. Cambiemos la escala de las calificaciones de un máximo de 5 a 100

# %%
# Usando la regla de 3 tenemos que la nueva columna (NC) respecto a la vieja (VC) se calcula como
#       NC= 100*VC/5

df2['NC']=100*df2['rating']/5

df2.head()
# Out:
#    userId  movieId  rating  timestamp     NC
# 0       1        1     4.0  964982703   80.0
# 1       1        3     4.0  964981247   80.0
# 2       1        6     4.0  964982224   80.0
# 3       1       47     5.0  964983815  100.0
# 4       1       50     5.0  964982931  100.0

# %% [markdown]
# ### 4. ¿Cuántas calificaciones tiene cada película? ¿Cuál es la calificación media de cada uno?

# %%
# Agrupamos las columnas de rating y movieId en terminos del movie Id para obtener 
Grouped=df2[['movieId','rating']].groupby('movieId')

# %%
Grouped.count()[:10]
# Out:
#          rating
# movieId
# 1           215
# 2           110
# 3            52
# 4             7
# 5            49
# 6           102
# 7            54
# 8             8
# 9            16
# 10          132

# %%
Grouped.mean()[:10]
# Out:
#            rating
# movieId
# 1        3.920930
# 2        3.431818
# 3        3.259615
# 4        2.357143
# 5        3.071429
# 6        3.946078
# 7        3.185185
# 8        2.875000
# 9        3.125000
# 10       3.496212

# %% [markdown]
# ### 5. ¿cuáles son las películas son las 20 mejores  y peores según las calificaciones? ¿Cuáles son las más calificadas?

# %%
# Las 20 mejores peliculas 
# Contamos los datos agrupados . Los ordenamos siguiendo el rating  de forma descendete. traemos las pimeras 10 columnas
Grouped.mean().sort_values(by='rating',ascending=False).iloc[:10]
# Out:
#          rating
# movieId
# 88448       5.0
# 100556      5.0
# 143031      5.0
# 143511      5.0
# 143559      5.0
# 6201        5.0
# 102217      5.0
# 102084      5.0
# 6192        5.0
# 145994      5.0

# %%
# Las 20 peores peliculas 
# Contamos los datos agrupados . Los ordenamos siguiendo el rating  de forma descendete. traemos las pimeras 10 columnas
Grouped.mean().sort_values(by='rating',ascending=False).iloc[-10:]
# Out:
#          rating
# movieId
# 44243       0.5
# 72424       0.5
# 6371        0.5
# 82684       0.5
# 137517      0.5
# 157172      0.5
# 85334       0.5
# 53453       0.5
# 8494        0.5
# 71810       0.5

# %%
# Peliculas más calficadas
# Contamos los datos agrupados . Los ordenamos siguiendo el rating  de forma descendete. traemos las pimeras 10 columnas
Grouped.mean().sort_values(by='rating',ascending=False).iloc[:10]
# Out:
#          rating
# movieId
# 88448       5.0
# 100556      5.0
# 143031      5.0
# 143511      5.0
# 143559      5.0
# 6201        5.0
# 102217      5.0
# 102084      5.0
# 6192        5.0
# 145994      5.0

# %% [markdown]
# ## 3. Pongamonos serios
#
# ### 1. La columna de genero en el DataFrame tiene divisiones, ¿podemos poner cada genero en una columna?

# %%
g=df1['Genero'].str.split('|',n=5,expand=True)
g.columns=['G1','G2','G3','G4','G5','G6']
g
# Out:
#                G1         G2        G3       G4        G5    G6
# 0       Adventure  Animation  Children   Comedy   Fantasy  None
# 1       Adventure   Children   Fantasy     None      None  None
# 2          Comedy    Romance      None     None      None  None
# 3          Comedy      Drama   Romance     None      None  None
# 4          Comedy       None      None     None      None  None
# 5          Action      Crime  Thriller     None      None  None
# 6          Comedy    Romance      None     None      None  None
# 7       Adventure   Children      None     None      None  None
# 8          Action       None      None     None      None  None
# 9          Action  Adventure  Thriller     None      None  None
# 10         Comedy      Drama   Romance     None      None  None
# 11         Comedy     Horror      None     None      None  None
# 12      Adventure  Animation  Children     None      None  None
# 13          Drama       None      None     None      None  None
# ...

# %% [markdown]
# ### 2. Concatena las nuevas columnas y quita la columna vieja

# %%
df1=pd.concat([df1, g], axis=1)
df1.drop(columns=['Genero']).head()
# Out:
#    ID                              Titulo         G1         G2        G3  \
# 0   1                    Toy Story (1995)  Adventure  Animation  Children
# 1   2                      Jumanji (1995)  Adventure   Children   Fantasy
# 2   3             Grumpier Old Men (1995)     Comedy    Romance      None
# 3   4            Waiting to Exhale (1995)     Comedy      Drama   Romance
# 4   5  Father of the Bride Part II (1995)     Comedy       None      None
#
#        G4       G5    G6
# 0  Comedy  Fantasy  None
# 1    None     None  None
# 2    None     None  None
# 3    None     None  None
# 4    None     None  None

# %% [markdown]
# ### 3. Agrega al dataframe pasado una columna de las calificaciones promedio

# %%
# Cambiemos los nombres de las columnas del segundo dataframe
df2.columns=['UID','ID','Cal','time','NC']

# Creamos la columna de la media
rat=df2[['ID','Cal']].groupby('ID').mean()

# %%
# Colocamos las mediciones a los IDs repectivos 
df1=df1.merge(rat,on='ID',how='inner')

# %%
df1
# Out:
#           ID                                             Titulo  \
# 0          1                                   Toy Story (1995)
# 1          2                                     Jumanji (1995)
# 2          3                            Grumpier Old Men (1995)
# 3          4                           Waiting to Exhale (1995)
# 4          5                 Father of the Bride Part II (1995)
# 5          6                                        Heat (1995)
# 6          7                                     Sabrina (1995)
# 7          8                                Tom and Huck (1995)
# 8          9                                Sudden Death (1995)
# 9         10                                   GoldenEye (1995)
# 10        11                     American President, The (1995)
# 11        12                 Dracula: Dead and Loving It (1995)
# 12        13                                       Balto (1995)
# 13        14                                       Nixon (1995)
# ...
