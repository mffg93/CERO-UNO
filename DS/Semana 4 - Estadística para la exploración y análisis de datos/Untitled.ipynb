# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Spotify

# %%
spotify=pd.read_csv('Spotify.csv')
spotify
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0      0.010200         0.833       204600   0.434
# 1              1      0.199000         0.743       326933   0.359
# 2              2      0.034400         0.838       185707   0.412
# 3              3      0.604000         0.494       199413   0.338
# 4              4      0.180000         0.678       392893   0.561
# 5              5      0.004790         0.804       251333   0.560
# 6              6      0.014500         0.739       241400   0.472
# 7              7      0.020200         0.266       349667   0.348
# 8              8      0.048100         0.603       202853   0.944
# 9              9      0.002080         0.836       226840   0.603
# 10            10      0.057200         0.525       358187   0.855
# 11            11      0.091500         0.753       324880   0.748
# 12            12      0.253000         0.603       356973   0.434
# ...

# %%
spotify.columns
# Out:
# Index(['Unnamed: 0', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'target',
#        'song_title', 'artist'],
#       dtype='object')

# %%
spotify2=spotify[['duration_ms','energy','tempo']]

# %%
spotify2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 3 columns):
# duration_ms    2017 non-null int64
# energy         2017 non-null float64
# tempo          2017 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 47.4 KB

# %%
 spotify2.describe()
# Out:
#         duration_ms       energy        tempo
# count  2.017000e+03  2017.000000  2017.000000
# mean   2.463062e+05     0.681577   121.603272
# std    8.198181e+04     0.210273    26.685604
# min    1.604200e+04     0.014800    47.859000
# 25%    2.000150e+05     0.563000   100.189000
# 50%    2.292610e+05     0.715000   121.427000
# 75%    2.703330e+05     0.846000   137.849000
# max    1.004627e+06     0.998000   219.331000

# %%
spotify2['duracion_min']=spotify2['duration_ms']/60000
# Out:
# /anaconda3/envs/curso/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
spotify2.head()
# Out:
#    duration_ms  energy    tempo  duracion_min
# 0       204600   0.434  150.062      3.410000
# 1       326933   0.359  160.083      5.448883
# 2       185707   0.412   75.044      3.095117
# 3       199413   0.338   86.468      3.323550
# 4       392893   0.561  174.004      6.548217

# %%
df1=pd.DataFrame({'x':range(2017),'y':spotify2['tempo']})
df1.plot.line(x='x',y='y',color='r')

# %%
spotify.describe()
# Out:
#         Unnamed: 0  acousticness  danceability   duration_ms       energy  \
# count  2017.000000   2017.000000   2017.000000  2.017000e+03  2017.000000
# mean   1008.000000      0.187590      0.618422  2.463062e+05     0.681577
# std     582.402066      0.259989      0.161029  8.198181e+04     0.210273
# min       0.000000      0.000003      0.122000  1.604200e+04     0.014800
# 25%     504.000000      0.009630      0.514000  2.000150e+05     0.563000
# 50%    1008.000000      0.063300      0.631000  2.292610e+05     0.715000
# 75%    1512.000000      0.265000      0.738000  2.703330e+05     0.846000
# max    2016.000000      0.995000      0.984000  1.004627e+06     0.998000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       2017.000000  2017.000000  2017.000000  2017.000000  2017.000000
# mean           0.133286     5.342588     0.190844    -7.085624     0.612295
# ...

# %%
agrupado=spotify.groupby('key')

# %%
agrupado['energy'].count()
# Out:
# key
# 0     216
# 1     257
# 2     184
# 3      63
# 4     105
# 5     166
# 6     159
# 7     212
# 8     136
# 9     191
# 10    141
# 11    187
# Name: energy, dtype: int64

# %%
agrupado['mode'].count().plot.bar()

# %%
len(spotify['artist'].unique())
# Out:
# 1343

# %%
len(spotify['song_title'].unique())
# Out:
# 1956

# %%
artistas=spotify.groupby('artist')

# %%
artistas.count().sort_values(by='mode',ascending=False)['mode'][:30].plot.bar()

# %%
Matrix=pd.plotting.scatter_matrix(spotify2, alpha=0.3)

# %%
print(spotify2.corr())
# Out:
#               duration_ms    energy     tempo  duracion_min
# duration_ms      1.000000 -0.144473 -0.076469      1.000000
# energy          -0.144473  1.000000  0.165721     -0.144473
# tempo           -0.076469  0.165721  1.000000     -0.076469
# duracion_min     1.000000 -0.144473 -0.076469      1.000000

# %%
spotify2['duracion_min'].plot.hist(bins=20)
